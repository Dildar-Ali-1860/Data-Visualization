# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
flight_data = pd.read_csv('flight_delays.csv')
flight_data
# Out:
#     Month        AA        AS         B6        DL         EV         F9  \
# 0       1  6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 1       2  7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 2       3  6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 3       4  4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 4       5  5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 5       6  8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 6       7  3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 7       8  3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 8       9 -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 9      10 -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 10     11  0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 11     12  4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %%
sns.lineplot(data=flight_data)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(data=flight_data,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Bar Chart

# %%
plt.figure(figsize=(10,6))
sns.barplot(x=flight_data.index,y=flight_data['NK'])
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %% [markdown]
# ## Scatter plots

# %%
#Another data
insurance_data = pd.read_csv('insurance.csv')
insurance_data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
insurance_data.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
insurance_data.corr()
# Out:
#                age       bmi  children   charges
# age       1.000000  0.109272  0.042469  0.299008
# bmi       0.109272  1.000000  0.012759  0.198341
# children  0.042469  0.012759  1.000000  0.067998
# charges   0.299008  0.198341  0.067998  1.000000

# %%
sns.lineplot(data=insurance_data)
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x=insurance_data.index,y=insurance_data['bmi'])
# Out:
# <AxesSubplot:ylabel='bmi'>

# %% [markdown]
# ## ScatterPlot

# %%
sns.scatterplot(x=insurance_data['bmi'],y=insurance_data['charges'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## Regression_line or RegPlot

# %%
sns.regplot(x=insurance_data['bmi'],y=insurance_data['charges'])
#to draw a regression line
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## Color-coded scatter plots

# %%
sns.scatterplot(x=insurance_data['bmi'],y=insurance_data['charges'],hue=insurance_data['smoker'])
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ## lmPlot

# %%
sns.lmplot(x='bmi',y='charges',hue='smoker',data=insurance_data)

# %% [markdown]
# # SwarmPlot

# %%
sns.swarmplot(x=insurance_data['smoker'],y=insurance_data['charges'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='smoker', ylabel='charges'>

# %% [markdown]
# # Another Data: Candy

# %%
candy_data = pd.read_csv('candy.csv')
candy_data
# Out:
#     id              competitorname chocolate fruity caramel peanutyalmondy  \
# 0    0                   100 Grand       Yes     No     Yes             No
# 1    1                3 Musketeers       Yes     No      No             No
# 2    2                   Air Heads        No    Yes      No             No
# 3    3                  Almond Joy       Yes     No      No            Yes
# 4    4                   Baby Ruth       Yes     No     Yes            Yes
# ..  ..                         ...       ...    ...     ...            ...
# 78  78                   Twizzlers        No    Yes      No             No
# 79  79                    Warheads        No    Yes      No             No
# 80  80        Welch's Fruit Snacks        No    Yes      No             No
# 81  81  Werther's Original Caramel        No     No     Yes             No
# 82  82                    Whoppers       Yes     No      No             No
#
# ...

# %%
candy_data.head()
# Out:
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %%
candy_data.corr()
# Out:
#                     id  sugarpercent  pricepercent  winpercent
# id            1.000000     -0.148374     -0.158402    0.043226
# sugarpercent -0.148374      1.000000      0.321587    0.207635
# pricepercent -0.158402      0.321587      1.000000    0.333861
# winpercent    0.043226      0.207635      0.333861    1.000000

# %%
candy_data.isnull().sum()
# Out:
# id                  0
# competitorname      0
# chocolate           0
# fruity              0
# caramel             0
# peanutyalmondy      0
# nougat              0
# crispedricewafer    0
# hard                0
# bar                 0
# pluribus            0
# sugarpercent        0
# pricepercent        0
# winpercent          0
# dtype: int64

# %%
sns.lineplot(data=candy_data)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(candy_data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot(x='sugarpercent',y='winpercent',hue='chocolate',data=candy_data)
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.swarmplot(x=candy_data['chocolate'],y=candy_data['sugarpercent'])
# Out:
# <AxesSubplot:xlabel='chocolate', ylabel='sugarpercent'>

# %%
plt.figure(figsize=(20,7))
sns.barplot(x=candy_data.id,y=candy_data['sugarpercent'])
# Out:
# <AxesSubplot:xlabel='id', ylabel='sugarpercent'>

# %%
sns.lmplot(x='id',y='sugarpercent',hue='chocolate',data=candy_data) #two lines

# %%
sns.scatterplot(x='sugarpercent',y='winpercent',data=candy_data)
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %%
sns.regplot(x='sugarpercent',y='winpercent',data=candy_data)
# Out:
# <AxesSubplot:xlabel='sugarpercent', ylabel='winpercent'>

# %% [markdown]
# # IRIS Data

# %%
iris_data = pd.read_csv('iris.csv')
iris_data
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width    Species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ## Histogram plot

# %%
sns.histplot(iris_data['Petal.Length'])
# Out:
# <AxesSubplot:xlabel='Petal.Length', ylabel='Count'>

# %%
sns.histplot(iris_data['Petal.Width'])
# Out:
# <AxesSubplot:xlabel='Petal.Width', ylabel='Count'>

# %%
iris_data.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.lineplot(x=iris_data['Sepal.Length'],y=iris_data['Petal.Width'])
# Out:
# <AxesSubplot:xlabel='Sepal.Length', ylabel='Petal.Width'>

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='Sepal.Width',y='Petal.Length',data=iris_data)
# Out:
# <AxesSubplot:xlabel='Sepal.Width', ylabel='Petal.Length'>

# %%
sns.swarmplot(x='Sepal.Width',y='Petal.Length',data=iris_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 9.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 16.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Sepal.Width', ylabel='Petal.Length'>

# %%
sns.lmplot(x='Sepal.Width',y='Petal.Length',hue='Species',data=iris_data)

# %% [markdown]
# ## Density plots:The type of plot is a kernel density estimate (KDE) plot

# %%
sns.kdeplot(iris_data['Sepal.Length'],shade=True)
# Out:
# <AxesSubplot:xlabel='Sepal.Length', ylabel='Density'>

# %%
sns.kdeplot(iris_data['Petal.Length'],shade=True)
# Out:
# <AxesSubplot:xlabel='Petal.Length', ylabel='Density'>

# %% [markdown]
# ### 2D KDE plots : Two-dimensional (2D) KDE plot with the sns.jointplot command.

# %%
sns.jointplot(x=iris_data['Petal.Length'],y=iris_data['Sepal.Width'],kind='kde')

# %% [markdown]
# # Color-coded plots

# %%
sns.histplot(data=iris_data,x='Sepal.Length',hue='Species')
# Out:
# <AxesSubplot:xlabel='Sepal.Length', ylabel='Count'>

# %%
sns.histplot(data=iris_data,x='Petal.Length',hue='Species')
# Out:
# <AxesSubplot:xlabel='Petal.Length', ylabel='Count'>

# %%
sns.kdeplot(data=iris_data,x='Sepal.Width',hue='Species',shade=True)
# Out:
# <AxesSubplot:xlabel='Sepal.Width', ylabel='Density'>

# %%
sns.kdeplot(data=iris_data,x='Petal.Length',hue='Species',shade=True)
# Out:
# <AxesSubplot:xlabel='Petal.Length', ylabel='Density'>

# %% [markdown]
# ## Another Data: Cancer Dataset

# %%
cancer_data = pd.read_csv('cancer.csv')
cancer_data
# Out:
#            Id Diagnosis  Radius (mean)  Texture (mean)  Perimeter (mean)  \
# 0     8510426         B         13.540           14.36             87.46
# 1     8510653         B         13.080           15.71             85.63
# 2     8510824         B          9.504           12.44             60.34
# 3      854941         B         13.030           18.42             82.61
# 4    85713702         B          8.196           16.84             51.71
# ..        ...       ...            ...             ...               ...
# 564    926125         M         20.920           25.09            143.00
# 565    926424         M         21.560           22.39            142.00
# 566    926682         M         20.130           28.25            131.20
# 567    926954         M         16.600           28.08            108.30
# 568    927241         M         20.600           29.33            140.10
#
#      Area (mean)  Smoothness (mean)  Compactness (mean)  Concavity (mean)  \
# ...

# %%
cancer_data.shape
# Out:
# (569, 32)

# %%
cancer_data.corr()
# Out:
#                                  Id  Radius (mean)  Texture (mean)  \
# Id                         1.000000       0.074626        0.099770
# Radius (mean)              0.074626       1.000000        0.323782
# Texture (mean)             0.099770       0.323782        1.000000
# Perimeter (mean)           0.073159       0.997855        0.329533
# Area (mean)                0.096893       0.987357        0.321086
# Smoothness (mean)         -0.012968       0.170581       -0.023389
# Compactness (mean)         0.000096       0.506124        0.236702
# Concavity (mean)           0.050080       0.676764        0.302418
# Concave points (mean)      0.044158       0.822529        0.293464
# Symmetry (mean)           -0.022114       0.147741        0.071401
# Fractal dimension (mean)  -0.052511      -0.311631       -0.076437
# Radius (se)                0.143048       0.679090        0.275869
# Texture (se)              -0.007526      -0.097317        0.386358
# ...

# %%
plt.figure(figsize=(20,7))
sns.lineplot(data=cancer_data)
# Out:
# <AxesSubplot:>

# %%
sns.swarmplot(x='Area (mean)',y='Concavity (mean)',data=cancer_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <AxesSubplot:xlabel='Area (mean)', ylabel='Concavity (mean)'>

# %%
sns.scatterplot(x='Area (mean)',y='Concavity (mean)',data=cancer_data)
# Out:
# <AxesSubplot:xlabel='Area (mean)', ylabel='Concavity (mean)'>

# %%
sns.lmplot(x='Area (mean)',y='Concavity (mean)',hue='Texture (worst)',data=cancer_data)

# %%
sns.regplot(x='Area (mean)',y='Concavity (mean)',data=cancer_data)
# Out:
# <AxesSubplot:xlabel='Area (mean)', ylabel='Concavity (mean)'>

# %%
sns.histplot(cancer_data['Area (mean)'])
# Out:
# <AxesSubplot:xlabel='Area (mean)', ylabel='Count'>

# %%
sns.histplot(data=cancer_data, x='Area (mean)', hue='Diagnosis')
# Out:
# <AxesSubplot:xlabel='Area (mean)', ylabel='Count'>

# %%
sns.kdeplot(x='Radius (worst)',data=cancer_data,shade=True,hue='Diagnosis')
# Out:
# <AxesSubplot:xlabel='Radius (worst)', ylabel='Density'>

# %%
sns.barplot(data=cancer_data,x='Area (mean)',y='Radius (worst)',hue='Diagnosis')
# Out:
# <AxesSubplot:xlabel='Area (mean)', ylabel='Radius (worst)'>

# %%
sns.barplot(data=cancer_data,x='Area (mean)',y='Radius (worst)',hue='Diagnosis')
# Out:
# <AxesSubplot:xlabel='Area (mean)', ylabel='Radius (worst)'>

# %%
sns.jointplot(x='Area (mean)',y='Radius (worst)',data=cancer_data, kind='kde')

# %%
sns.jointplot(x='Area (worst)',y='Radius (mean)',data=cancer_data, kind='kde')

# %% [markdown]
# # Choosing Plot Types and Custom Styles

# %% [markdown]
# ## Spotify Dataset

# %%
spotify_data=pd.read_csv('spotify.csv')
spotify_data
# Out:
#            Date  Shape of You  Despacito  Something Just Like This    HUMBLE.  \
# 0    2017-01-06      12287078        NaN                       NaN        NaN
# 1    2017-01-07      13190270        NaN                       NaN        NaN
# 2    2017-01-08      13099919        NaN                       NaN        NaN
# 3    2017-01-09      14506351        NaN                       NaN        NaN
# 4    2017-01-10      14275628        NaN                       NaN        NaN
# ..          ...           ...        ...                       ...        ...
# 361  2018-01-05       4492978  3450315.0                 2408365.0  2685857.0
# 362  2018-01-06       4416476  3394284.0                 2188035.0  2559044.0
# 363  2018-01-07       4009104  3020789.0                 1908129.0  2350985.0
# 364  2018-01-08       4135505  2755266.0                 2023251.0  2523265.0
# 365  2018-01-09       4168506  2791601.0                 2058016.0  2727678.0
#
#      Unforgettable
# ...

# %%
sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:>

# %%
# Change the style of the figure to the "dark" theme

sns.set_style('dark')
plt.figure(figsize=(15,7))

sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:>

# %%
sns.set_style('darkgrid')
plt.figure(figsize=(15,7))

sns.lineplot(data=spotify_data)
# Out:
# <AxesSubplot:>
